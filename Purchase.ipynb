# %%
import json

fd = open("product.json",'r')
r = fd.read()
fd.close()


record = json.loads(r)

# %%
record
# Out:
# {'101': {'Name': 'TATA Salt',
#   'Weight': '1 kg',
#   'Price': '30',
#   'Quantity': '100'},
#  '102': {'Name': 'Maggi', 'Weight': '100 gm', 'Price': '17', 'Quantity': 147},
#  '103': {'Name': 'Red Bull Energy Drink',
#   'Weight': '250 ml',
#   'Price': '105',
#   'Quantity': '25'},
#  '104': {'Name': 'Dabur Honey',
#   'Weight': '400 gm',
#   'Price': '125',
#   'Quantity': '30'},
#  '105': {'Name': 'Jim Jam Biscuit',
#   'Weight': '150 gm',
#   'Price': '34',
#   'Quantity': 48},
#  '106': {'Name': 'Marie Gold Biscuit',
#   'Weight': '250 gm',
#   'Price': '30',
#   'Quantity': '67'},
#  '107': {'Name': 'Nescafe Coffee',
#   'Weight': '100 gm',
#   'Price': '285',
#   'Quantity': 41},
#  '108': {'Name': 'Chocalate syrup',
#   'Weight': '623 gm',
#   'Price': '170',
#   'Quantity': 9},
#  '109': {'Name': 'Kissan Tomato Ketchup',
#   'Weight': '950 gm',
#   'Price': '113',
#   'Quantity': 43},
#  '110': {'Name': 'Oreo Biscuit',
#   'Weight': '300 gm',
#   'Price': '80',
# ...

# %%
list_product = {'101 ': {'Name': 'TATA Salt','Weight': '1 kg','Price': '30'},
             '102': {'Name': 'Maggi', 'Weight': '150 gm', 'Price': '17'},
             '103': {'Name': 'Red Bull Energy Drink','Weight': '250 ml','Price': '105'},
             '104': {'Name': 'Dabur Honey','Weight': '400 gm','Price': '125'},
             '105': {'Name': 'Jim Jam Biscuit', 'Weight': '150 gm','Price': '34'},
             '106': {'Name': 'Marie Gold Biscuit','Weight': '250 gm','Price': '30'},
             '107': {'Name': 'Nescafe Coffee','Weight': '100 gm','Price': '285'},
             '108': {'Name': 'Chocalate syrup', 'Weight': '623 gm','Price': '170'},
             '109': {'Name': 'Kissan Tomato Ketchup','Weight': '950 gm','Price': '113'},
             '110': {'Name': 'Oreo Biscuit','Weight': '300 gm','Price': '80'},
             '111': {'Name': 'Black Dates','Weight': '800 gm','Price': '299'},
             '112': {'Name': 'Red Label Tea', 'Weight': '1 kg','Price': '501'},
             '113': {'Name': 'Peanut Butter', 'Weight': '510 gm', 'Price': '295'},
             '114': {'Name': 'Lays Potato Chips',  'Weight': '52 gm', 'Price': '20'},
             '115': {'Name': 'Taj Mahal Tea', 'Weight': '500 gm', 'Price': '350'},
             '116': {'Name': 'Good Day cashew','Weight': '200 gm','Price': '35'},
             '117 ': {'Name': 'Fortune Atta',  'Weight': '10 kg','Price': '150'},
             '118': {'Name': 'Kissan Jam', 'Weight': '1 kg','Price': '250'},
             '119': {'Name': 'Thumps Up', 'Weight': '750 ml', 'Price': '40'},
             '123': {'Name': 'Rin', 'Weight': '7 kg', 'Price': '494', 'Quantity': '96'},
             '124': {'Name': 'Haric', 'Weight': '1 L', 'Price': '165', 'Quantity': '46'},
             '125': {'Name': 'Lizol', 'Weight': '2 L', 'Price': '334', 'Quantity': '25'},
             '126': {'Name': 'Dettol Liquid',  'Weight': '1 L', 'Price': '312'},
             '127': {'Name': 'Odonil', 'Weight': '50 gm', 'Price': '50', 'Quantity': '96'},
             '128': {'Name': 'Vim Bar', 'Weight': '200 gm', 'Price': '20'},
             '129': {'Name': 'Colgate','Weight': '150 gm','Price': '60'},
             '130': {'Name': 'Dettol Handwash', 'Weight': '1.5 L',  'Price': '198'}
            }

# %%
Customer_Name = str(input("Enter your Name:"))
print("Welcome",Customer_Name,"!!!!")
print("TO see the product list please enter 1")
ch = int(input("Please press 1: "))

if(ch == 1):
    print(list_product)
    
else:
    print("Please press 1")
# Out:
# Enter your Name:Saloni
# Welcome Saloni !!!!
# TO see the product list please enter 1
# Please press 1: 1
# ...

# %%
ui_prod = str(input("Enter the product_ID: "))
if ui_prod not in record.keys():
        print("Sorry!!!No product found for ID: ",ui_prod,"\Please enter valid product ID")
        
else:
    ui_quant = int(input("Enter the quantity: "))

for i in record.keys():
    while ui_prod == i:
        if(record[ui_prod]['Quantity'] == 0 or ui_quant >int(record[ui_prod]['Quantity']) ):
            print("Sorry we don't have this product right now")

        else:
                print("Product: ", record[ui_prod]['Name'])
                print("Price: ", record[ui_prod]['Price'])
                print("**********************************************")
                print("Billing Amount: ",int(record[ui_prod]['Price'])*int(ui_quant))
                
                print("**********************************************")
                print("Thanks For Shopping")
                print("**********************************************")
                print("!!!!!VISIT AGAIN!!!!!!")
                
                
        break
# Out:
# Enter the product_ID: 116
# Enter the quantity: 3
# Product:  Good Day cashew
# Price:  35
# **********************************************
# Billing Amount:  105
# **********************************************
# Thanks For Shopping
# **********************************************
# !!!!!VISIT AGAIN!!!!!!

# %%
record[ui_prod]['Quantity'] = int(record[ui_prod]['Quantity']) - int(ui_quant)

js = json.dumps(record)

fd=open("product.json",'w')
fd.write(js)
fd.close()

# %%
js
# Out:
# '{"101": {"Name": "TATA Salt", "Weight": "1 kg", "Price": "30", "Quantity": "100"}, "102": {"Name": "Maggi", "Weight": "100 gm", "Price": "17", "Quantity": 147}, "103": {"Name": "Red Bull Energy Drink", "Weight": "250 ml", "Price": "105", "Quantity": "25"}, "104": {"Name": "Dabur Honey", "Weight": "400 gm", "Price": "125", "Quantity": "30"}, "105": {"Name": "Jim Jam Biscuit", "Weight": "150 gm", "Price": "34", "Quantity": 48}, "106": {"Name": "Marie Gold Biscuit", "Weight": "250 gm", "Price": "30", "Quantity": "67"}, "107": {"Name": "Nescafe Coffee", "Weight": "100 gm", "Price": "285", "Quantity": 41}, "108": {"Name": "Chocalate syrup", "Weight": "623 gm", "Price": "170", "Quantity": 9}, "109": {"Name": "Kissan Tomato Ketchup", "Weight": "950 gm", "Price": "113", "Quantity": 43}, "110": {"Name": "Oreo Biscuit", "Weight": "300 gm", "Price": "80", "Quantity": "100"}, "111": {"Name": "Black Dates", "Weight": "800 gm", "Price": "299", "Quantity": "98"}, "112": {"Name": "Red Label Tea", "
# ...

# %%
import json

fd = open("product.json",'r')
r = fd.read()
fd.close()







record = json.loads(r)

# %%
record
# Out:
# {'101': {'Name': 'TATA Salt',
#   'Weight': '1 kg',
#   'Price': '30',
#   'Quantity': '100'},
#  '102': {'Name': 'Maggi', 'Weight': '100 gm', 'Price': '17', 'Quantity': 147},
#  '103': {'Name': 'Red Bull Energy Drink',
#   'Weight': '250 ml',
#   'Price': '105',
#   'Quantity': '25'},
#  '104': {'Name': 'Dabur Honey',
#   'Weight': '400 gm',
#   'Price': '125',
#   'Quantity': '30'},
#  '105': {'Name': 'Jim Jam Biscuit',
#   'Weight': '150 gm',
#   'Price': '34',
#   'Quantity': 48},
#  '106': {'Name': 'Marie Gold Biscuit',
#   'Weight': '250 gm',
#   'Price': '30',
#   'Quantity': '67'},
#  '107': {'Name': 'Nescafe Coffee',
#   'Weight': '100 gm',
#   'Price': '285',
#   'Quantity': 41},
#  '108': {'Name': 'Chocalate syrup',
#   'Weight': '623 gm',
#   'Price': '170',
#   'Quantity': 9},
#  '109': {'Name': 'Kissan Tomato Ketchup',
#   'Weight': '950 gm',
#   'Price': '113',
#   'Quantity': 43},
#  '110': {'Name': 'Oreo Biscuit',
#   'Weight': '300 gm',
#   'Price': '80',
# ...

# %% [markdown]
# The sold items information is stored on sale.json

# %%
initial_count = {'n_sales':0}
r = json.dumps(initial_count)

fd = open("sales.json",'w')
fd.write(data)
fd.close()

# %%
sales_fp = open("sales.json",'r')
r = sales_fp.read()
sales_fp.close()

sales = json.loads(r)

sales['n_sales'] += 1
i = sales['n_sales']

sale={'product id':ui_prod,'name':record[ui_prod]['Name'],'Price':record[ui_prod]['Price'],'quantity':ui_quant,'Billing Amount'
     :int(record[ui_prod]['Price'])*int(ui_quant)}
sales[i] = sale


print(i)
print(sales[i])
# Out:
# 4
# {'product id': '116', 'name': 'Good Day cashew', 'Price': '35', 'quantity': 3, 'Billing Amount': 105}
# 4

# %%
sales
# Out:
# {'n_sales': 4,
#  '1': {'product id': '108', 'name': 'Chocalate syrup'},
#  '2': {'product id': '108', 'name': 'Chocalate syrup'},
#  '3': {'product id': '116',
#   'name': 'Good Day cashew',
#   'Price': '35',
#   'quantity': 3,
#   'Billing Amount': 105},
#  4: {'product id': '116',
#   'name': 'Good Day cashew',
#   'Price': '35',
#   'quantity': 3,
#   'Billing Amount': 105}}

# %%
r= json.dumps(sales)

sales_fp = open("sales.json",'a')
sales_fp.write(r)
sales_fp.close()
